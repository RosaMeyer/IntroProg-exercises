# %%
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
from dstapi import DstApi # install with `pip install git+https://github.com/alemartinello/dstapi`

# %%
file = 'EDP2.csv'
df = pd.read_csv(file, encoding='latin-1') # skiprows=2, sep = ','

df
# Out:
#    Offentligt underskud og gæld i EU-landene efter enhed   funktion   land
# 0                                              og tid           NaN    NaN
# 1    ," "," ","2000","2001","2002","2003","2004","...           NaN    NaN
# 2                          Mio. Euro (løbende priser)           NaN    NaN
# 3                  ,"Offentlig bruttogæld (ØMU-gæld)"           NaN    NaN
# 4    ," ","Belgien",280959.5,286055.5,288110.8,285...           NaN    NaN
# 5    ," ","Bulgarien",10177.1,10269.8,8890.3,8126....           NaN    NaN
# 6    ," ","Cypern",6024.5,6660.9,7339.8,8184.8,905...           NaN    NaN
# 7    ," ","Danmark",93084.0,89464.7,93174.5,89061....           NaN    NaN
# 8    ," ","Estland",315.6,333.4,442.9,489.7,499.9,...           NaN    NaN
# 9    ," ","Finland",61564.0,62825.0,63299.0,68508....           NaN    NaN
# 10   ," ","Frankrig",870626.0,897446.0,956794.0,10...           NaN    NaN
# ...

# %%
# Read and store content 
# of an excel file 

file = 'EDP3.xlsx'
dt = pd.read_excel(file, skiprows=[1]) # encoding='latin-1') # skiprows=2, sep = ','

# %%
dt
# Out:
#    Offentligt underskud og gæld i EU-landene efter enhed, funktion, land og tid  \
# 0                                                 NaN
# 1                          Mio. Euro (løbende priser)
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
# Write the dataframe object 
# into csv file 
dt.to_csv('Test.csv', index=None, header=True)
dt = pd.DataFrame(pd.read_csv("Test.csv")) 
  
# show the dataframe 
dt
# Out:
#    Offentligt underskud og gæld i EU-landene efter enhed, funktion, land og tid  \
# 0                                                 NaN
# 1                          Mio. Euro (løbende priser)
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
d = pd.read_csv('Test.csv', encoding='latin-1') # skiprows=2, sep = ','

# %%
d
# Out:
#    Offentligt underskud og gÃ¦ld i EU-landene efter enhed, funktion, land og tid  \
# 0                                                 NaN
# 1                         Mio. Euro (lÃ¸bende priser)
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...
